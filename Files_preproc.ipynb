# %%
import glob
import re
import pandas as pd
import numpy as np
import copy
import calendar

files_txt = glob.glob(r'images/[0-9]*/*/*[.txt|.TXT]')
mtl_regex = re.compile('(.*/.*MTL.*)')

files_metadata = []
for file_path in files_txt:
    matched = mtl_regex.match(file_path)
    if matched is not None:
        files_metadata.append(matched.group())

# %%
files_metadata
# Out:
# ['images/1/EO1A2260862014101110K2_1T/EO1A2260862014101110K2_MTL_L1T.TXT',
#  'images/1/EO1H2260862014101110K2_1T/EO1H2260862014101110K2_MTL_L1T.TXT',
#  'images/1/LC08_L1TP_226086_20140414_20170423_01_T1/LC08_L1TP_226086_20140414_20170423_01_T1_MTL.txt',
#  'images/10/EO1A2240692014363110KF_1T/EO1A2240692014363110KF_MTL_L1T.TXT',
#  'images/10/EO1H2240692014363110KF_1T/EO1H2240692014363110KF_MTL_L1T.TXT',
#  'images/10/LC08_L1TP_224069_20141228_20170415_01_T1/LC08_L1TP_224069_20141228_20170415_01_T1_MTL.txt',
#  'images/11/EO1A1960522014361110KF_1T/EO1A1960522014361110KF_MTL_L1T.TXT',
#  'images/11/EO1H1960522014361110KF_1T/EO1H1960522014361110KF_MTL_L1T.TXT',
#  'images/11/LC08_L1TP_196052_20141224_20170416_01_T1/LC08_L1TP_196052_20141224_20170416_01_T1_MTL.txt',
#  'images/12/EO1A1410452014354110KZ_1T/EO1A1410452014354110KZ_MTL_L1T.TXT',
#  'images/12/EO1H1410452014354110KZ_1T/EO1H1410452014354110KZ_MTL_L1T.TXT',
#  'images/12/LC08_L1TP_141045_20141223_20170416_01_T1/LC08_L1TP_141045_20141223_20170416_01_T1_MTL.txt',
#  'images/13/EO1A1940522014352110KF_1T/EO1A1940522014352110KF_MTL_L1T.TXT',
#  'images/13/EO1H1940522014352110KF_1T/EO1H1940522014352110KF_MTL_L1T.TXT',
#  'images/13/LC08_L1TP_194052_20141210_20170416_01_T1/LC08_L1TP_194052_20141210_20170416_01_T1_MTL.txt',
#  'images/14/EO1A0010852014359110K4_1T/EO1A0010852014359110K4_MTL_L1T.TXT',
#  'images/14/EO1H0010852014359110K4_1T/EO1H0010852014359110K4_MTL_L1T.TXT',
#  'images/14/LC08_L1TP_001085_20141218_20170416_01_T1/LC08_L1TP_001085_20141218_20170416_01_T1_MTL.txt',
#  'images/15/EO1A0430332015055110P3_1T/EO1A0430332015055110P3_MTL_L1T.TXT',
#  'images/15/EO1H0430332015055110P3_1T/EO1H0430332015055110P3_MTL_L1T.TXT',
#  'images/15/LC08_L1TP_043033_20150226_20180201_01_T1/LC08_L1TP_043033_20150226_20180201_01_T1_MTL.txt',
#  'images/16/EO1A1460462015052110KZ_1T/EO1A1460462015052110KZ_MTL_L1T.TXT',
#  'images/16/EO1H1460462015052110KZ_1T/EO1H1460462015052110KZ_MTL_L1T.TXT',
#  'images/16/LC08_L1TP_146046_20150212_20170413_01_T1/LC08_L1TP_146046_20150212_20170413_01_T1_MTL.txt',
#  'images/2/EO1A1120762014141110KF_1T/EO1A1120762014141110KF_MTL_L1T.TXT',
#  'images/2/EO1H1120762014141110KF_1T/EO1H1120762014141110KF_MTL_L1T.TXT',
                    product_corners_eo
    nScene_regex = re.compile('images/([0-9]*)/.*')
    
    df_metadata = pd.DataFrame(columns = meta_cols)
    
    for file in files:
        f = open(file, "r")
        file_str = f.read()
        file_metadata = {}
        file_metadata['SceneNumber'] = nScene_regex.match(file).groups()[0]
        for col in meta_cols:
            pattern = re.compile('.*'+col+'.* = (.*)\\n.*')
            matched = pattern.findall(file_str)
            if len(matched) == 0:
                if col == 'WRS_PATH':
                    matched = re.findall('.*/EO1\w(\d{3})\d{3}.*', file)
                    file_metadata[col] = matched[0]
                if col == 'WRS_ROW':
                    matched = re.findall('.*/EO1\w\d{3}(\d{3}).*', file)
                    file_metadata[col] = matched[0]
                elif col == 'PRODUCT_TYPE':
                    pattern = re.compile('.*DATA_TYPE = (.*)\\n.*')
                    matched = pattern.findall(file_str)
                    file_metadata[col] = matched[0].strip('"')
                elif col == 'DATUM':
                    pattern = re.compile('.*REFERENCE_DATUM = (.*)\\n.*')
                    matched = pattern.findall(file_str)
                    file_metadata[col] = matched[0]
                elif col == 'PRODUCT_ID':
                    matched = re.findall('(EO[A-Z0-9]*)_.*', file)
#                    pattern = re.compile('.*REQUEST_ID = (.*)\\n.*')
#                    matched = pattern.findall(file_str)
                    file_metadata[col] = matched[0]
                elif 'CORNER' in col:
                    file_metadata[col] = re.findall('.*{} = (.*)\\n.*'.format(corners_dict[col]), file_str)[0]
                elif 'DATE' in col:
                    file_metadata[col] = re.findall('.*DATE_ACQUIRED = (.*)\\n.*', file_str)[0]
            else:
                file_metadata[col] = matched[0].strip('"')
        df_metadata = df_metadata.append(file_metadata, ignore_index = True)
        f.close()
    return df_metadata

# %%
df_metadata = create_dataset(files_metadata)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-8b414030ab5a> in <module>
# ----> 1 df_metadata = create_dataset(files_metadata)
#       2 df_metadata.sort_values(by = 'SceneNumber').head(50)
#
# <ipython-input-13-ac37f4a8466e> in create_dataset(save_dataset, return_dataset, output_path_filename)
#      65                     file_metadata[col] = re.findall(r'.*{} = (.*)\\n.*'.format(corners_dict[col]), file_str)[0]
#      66                 elif 'DATE' in col:
# ---> 67                     file_metadata[col] = re.findall(r'.*DATE_ACQUIRED = (.*)\\n.*', file_str)[0]
#      68             else:
#      69                 file_metadata[col] = matched[0].strip('"')
#
# IndexError: list index out of range

# %%
df_metadata.columns
# Out:
# Index(['SceneNumber', 'SPACECRAFT_ID', 'SENSOR_ID', 'ACQUISITION_DATE',
#        'PRODUCT_ID', 'WRS_PATH', 'WRS_ROW', 'PRODUCT_TYPE', 'DATUM',
#        'MAP_PROJECTION', 'PRODUCT_UL_CORNER_LAT', 'PRODUCT_UR_CORNER_LAT',
#        'PRODUCT_LL_CORNER_LAT', 'PRODUCT_LR_CORNER_LAT',
#        'PRODUCT_UL_CORNER_LON', 'PRODUCT_UR_CORNER_LON',
#        'PRODUCT_LL_CORNER_LON', 'PRODUCT_LR_CORNER_LON', 'CENTER_LAT',
#        'CENTER_LON', 'MODTRAN_ATMOSPHERE'],
#       dtype='object')

# %%
df_metadata.sort_values(by = 'ACQUISITION_DATE').head(100)
# Out:
#    SceneNumber SPACECRAFT_ID SENSOR_ID          ACQUISITION_DATE  \
# 13              -1.042245              -0.782008     10.8890     -0.9090
# 17             -74.350390             -71.691330    -36.0395    -73.0473
# 12              -1.009835              -0.456689     10.8660     -0.7295
# 9               83.400393              83.912855     22.1056     83.6661
# 10              83.369289              83.638671     22.1326     83.5125
# 11              82.774670              84.937180     21.6626     83.8766
# 8               -4.421900              -2.341080     11.5628     -3.3829
# 16             -73.217402             -72.761333    -36.6200    -73.0042
# 15             -73.174966             -72.447999    -36.6477    -72.8290
# 7               -3.535821              -3.255069     12.1195     -3.3961
# 6               -3.497196              -2.941290     12.1046     -3.2196
# 5              -52.968830             -50.857360    -13.0126    -51.9093
# 4              -52.465712             -52.202870    -12.6219    -52.3318
# 3              -52.435594             -51.915298    -12.6402    -52.1731
# 23              74.729880              76.892400     20.2221     75.8166
# 21              75.226610              75.749315     19.8552     75.4895
# 22              75.198128              75.483884     19.8909     75.3420
# 18            -121.213255            -120.358488     38.5024   -120.7550
# 19            -121.245667            -120.671841     38.5318   -120.9314
# 20            -121.487630            -118.905970     38.8910   -120.1553
#
#     MODTRAN_ATMOSPHERE
# 0                  SAS
# 1                  SAS
# 2                  SAS
# 26                   T
# 25                   T
# 24                   T
# 35                 SAS
# 32                 MLS
# 40                 MLS
# 39                 MLS
# 36                 SAS
# 37                 SAS
# 34                 SAS
# 33                 SAS
# 31                 MLS
# 30                 MLS
# 41                 MLS
# 38                 SAS
# 44                 MLS
# 43                 MLS
# 42                 MLS
# 47                 MLS
# 46                 MLS
# 45                 MLS
# 27                   T
# 28                   T
# 29                   T
# 14                   T
# 13                   T
# 17                 SAS
# 12                   T
# 9                    T
# 10                   T
# 11                   T
# 8                    T
# 16                 SAS
# 15                 SAS
# 7                    T
# 6                    T
# 5                    T
# 4                    T
# 3                    T
# 23                   T
# 21                   T
# 22                   T
# 18                 SAS
# 19                 SAS
# 20                 SAS
#
# [48 rows x 21 columns]

# %%
df_metadata.dtypes
col_corners = df_metadata.filter(regex = r'CORNER').columns

data_types = {
    'ACQUISITION_DATE': pd.DatetimeTZDtype(tz = 'UTC'),
    'WRS_PATH': 'int32',
    'WRS_ROW': 'int32'}

data_types.update(dict(zip(col_corners, ['float64']*len(col_corners))))

df_metadata = df_metadata.astype(data_types)
df_metadata.dtypes
# Out:
# SceneNumber                           object
# SPACECRAFT_ID                         object
# SENSOR_ID                             object
# ACQUISITION_DATE         datetime64[ns, UTC]
# PRODUCT_ID                            object
# WRS_PATH                               int32
# WRS_ROW                                int32
# PRODUCT_TYPE                          object
# DATUM                                 object
# MAP_PROJECTION                        object
# PRODUCT_UL_CORNER_LAT                float64
# PRODUCT_UR_CORNER_LAT                float64
# PRODUCT_LL_CORNER_LAT                float64
# PRODUCT_LR_CORNER_LAT                float64
# PRODUCT_UL_CORNER_LON                float64
# PRODUCT_UR_CORNER_LON                float64
# PRODUCT_LL_CORNER_LON                float64
# PRODUCT_LR_CORNER_LON                float64
# dtype: object

# %%
df_metadata['CENTER_LAT'] = df_metadata.apply(lambda row: np.round(row.filter(regex = 'LAT').values.mean(), 4), axis = 1)
df_metadata['CENTER_LON'] = df_metadata.apply(lambda row: np.round(row.filter(regex = 'LON').values.mean(), 4), axis = 1)

# %% [markdown]
# Dentro de la configuración de la correción atmosférica de FLAASH en ENVI, se requiere ingresar el modelo atmosférico de MODTRAN, dentro del manual del módulo de flaash se muestran distintas formas de determinar este modelo, dos de las cuales requieren saber la temperatuar a nivel de superficie del terreno, puesto que no tengo esa información, usaré le tercer método consistente en determinar el modelo según la latitud y el mes del año.

# %%
modtran_atm = pd.read_csv('MODTRAN atmospheres.csv', index_col = 'Latitude(°N)')
modtran_atm
# Out:
#              January February March April  May June July August September  \
# Latitude(°N)
#  80              SAW      SAW   SAW   SAW  SAW  MLW  MLW    MLW       MLW
#  70              SAW      SAW   SAW   MLW  MLW  MLW  MLW    MLW       MLW
#  60              MLW      MLW   MLW   MLW  MLW  SAS  SAS    SAS       SAS
#  50              MLW      MLW   MLW   SAS  SAS  SAS  SAS    SAS       SAS
#  40              SAS      SAS   SAS   SAS  SAS  MLS  MLS    MLS       MLS
#  30              MLS      MLS   MLS   MLS  MLS    T    T      T         T
#  20                T        T     T     T    T    T    T      T         T
#  10                T        T     T     T    T    T    T      T         T
#  0                 T        T     T     T    T    T    T      T         T
# -10                T        T     T     T    T    T    T      T         T
# -20                T        T     T     T    T  MLS  MLS    MLS       MLS
# -30              MLS      MLS   MLS   MLS  MLS  MLS  MLS    MLS       MLS
# -40              SAS      SAS   SAS   SAS  SAS  SAS  SAS    SAS       SAS
# -50              SAS      SAS   SAS   SAS  SAS  MLW  MLW    MLW       MLW
# -60              MLW      SAS   SAS   MLW  MLW  MLW  MLW    MLW       MLW
# -70              MLW      MLW   MLW   MLW  MLW  MLW  MLW    MLW       MLW
# -80              MLW      MLW   MLW   MLW  MLW  SAW  SAW    MLW       MLW
#
#              October November December
# Latitude(°N)
#  80              MLW      SAW      SAW
#  70              MLW      SAW      SAW
#  60              SAS      MLW      MLW
#  50              SAS      SAS      SAS
#  40              MLS      SAS      SAS
#  30                T      MLS      MLS
#  20                T        T        T
#  10                T        T        T
#  0                 T        T        T
# -10                T        T        T
# -20              MLS        T        T
# -30              MLS      MLS      MLS
# -40              SAS      SAS      SAS
# -50              MLW      SAS      SAS
# -60              MLW      MLW      MLW
# -70              MLW      MLW      MLW
# -80              MLW      MLW      MLW

# %%
months_dict = dict((k,v) for k,v in enumerate(calendar.month_name))

df_metadata['MODTRAN_ATMOSPHERE'] = df_metadata.apply(lambda row: modtran_atm.loc[np.round((row.CENTER_LAT),-1).astype(int), months_dict[row.ACQUISITION_DATE.month]], axis = 1)

# %%
def create_dataset(save_dataset = False, return_dataset = True, output_path_filename = 'img_metadata.csv'):
   # Variables
    data_types = {
        'ACQUISITION_DATE': pd.DatetimeTZDtype(tz = 'UTC'),
        'WRS_PATH': 'int32',
        'WRS_ROW': 'int32'}

    files_txt = glob.glob(r'images/[0-9]/*/*[.txt|.TXT]')
    mtl_regex = re.compile('(.*/.*MTL.*)')
    files_metadata = []

    corners = ['UL', 'UR', 'LL', 'LR']
    product_corners_eo = ['PRODUCT_{}_CORNER_LAT'.format(corner) for corner in corners] +\
                        ['PRODUCT_{}_CORNER_LON'.format(corner) for corner in corners]
    product_corners_landsat = ['CORNER_{}_LAT_PRODUCT'.format(corner) for corner in corners] +\
                        ['CORNER_{}_LON_PRODUCT'.format(corner) for corner in corners]

    # This dict is needed since the syntax for EO-1 products and Landsat 8 is different for the corners coords
    corners_dict = dict(zip(product_corners_eo, product_corners_landsat)) 

    meta_cols = ['SceneNumber', 'SPACECRAFT_ID', 'SENSOR_ID', 'ACQUISITION_DATE', 'PRODUCT_ID', 'WRS_PATH', 'WRS_ROW','PRODUCT_TYPE',
                'DATUM', 'MAP_PROJECTION'] +  product_corners_eo
    nScene_regex = re.compile('images/([0-9]*)/.*')


    df_metadata = pd.DataFrame(columns = meta_cols)
    
    # File reading
    ## get metadata filenames
    for file_path in files_txt:
        matched = mtl_regex.match(file_path)
        if matched is not None:
            files_metadata.append(matched.group())
    
    ## Read the metadata files of each image
    for file in files_metadata:
        #print('Reading {} ...\n'.format(file))
        f = open(file, "r")
        file_str = f.read()
        file_metadata = {}
        file_metadata['SceneNumber'] = nScene_regex.match(file).groups()[0]

        for col in meta_cols:
            pattern = re.compile(r'.*'+col+'.* = (.*)\\n.*')
            matched = pattern.findall(file_str)
            if len(matched) == 0:
                if col == 'WRS_PATH':
                    matched = re.findall(r'.*/EO1\w(\d{3})\d{3}.*', file)
                    file_metadata[col] = matched[0]
                if col == 'WRS_ROW':
                    matched = re.findall(r'.*/EO1\w\d{3}(\d{3}).*', file)
                    file_metadata[col] = matched[0]
                elif col == 'PRODUCT_TYPE':
                    pattern = re.compile(r'.*DATA_TYPE = (.*)\\n.*')
                    matched = pattern.findall(file_str)
                    file_metadata[col] = matched[0].strip('"')
                elif col == 'DATUM':
                    pattern = re.compile(r'.*REFERENCE_DATUM = (.*)\\n.*')
                    matched = pattern.findall(file_str)
                    file_metadata[col] = matched[0]
                elif col == 'PRODUCT_ID':
                    matched = re.findall(r'(EO[A-Z0-9]*)_.*', file)
                    file_metadata[col] = matched[0]
                elif 'CORNER' in col:
                    file_metadata[col] = re.findall(r'.*{} = (.*)\\n.*'.format(corners_dict[col]), file_str)[0]
                elif 'DATE' in col:
                    file_metadata[col] = re.findall(r'.*DATE_ACQUIRED = (.*)\\n.*', file_str)[0]
            else:
                file_metadata[col] = matched[0].strip('"')
        df_metadata = df_metadata.append(file_metadata, ignore_index = True)
        f.close()

    # Preprocessing code
    #df = create_dataset(files_metadata)
    col_corners = df_metadata.filter(regex = r'CORNER').columns

    data_types.update(dict(zip(col_corners, ['float64']*len(col_corners))))

    # Center of the image
    df_metadata = df_metadata.astype(data_types)
    df_metadata['CENTER_LAT'] = df_metadata.apply(lambda row: np.round(row.filter(regex = 'LAT').values.mean(), 4), axis = 1)
    df_metadata['CENTER_LON'] = df_metadata.apply(lambda row: np.round(row.filter(regex = 'LON').values.mean(), 4), axis = 1)

    '''
    In the atmospheric correction of FLAASH in ENVI, its required the MODTRAN model. On the FLAASH user guide various methods are showed for
    determining the corresponding atmospheric modelo to use. This script will calculate the model based in the latitude of the center point
    of the image and the month of the year.
    '''

    months_dict = dict((k,v) for k,v in enumerate(calendar.month_name))
    modtran_atm = pd.read_csv('MODTRAN atmospheres.csv', index_col = 'Latitude(°N)')

    df_metadata['MODTRAN_ATMOSPHERE'] = df_metadata.apply(lambda row: modtran_atm.loc[
                                                                np.round((row.CENTER_LAT),-1).astype(int),
                                                                months_dict[row.ACQUISITION_DATE.month]],
                                                                axis = 1)

    if save_dataset is True:
        print('save')
        df_metadata.to_csv(output_path_filename, index = False)
    if return_dataset is True:
        return df_metadata

# %%
#from data_preproc import create_dataset
df_test = create_dataset(return_dataset=True, save_dataset=True)
df_test
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-e21e75a0ec8c> in <module>
#       1 #from data_preproc import create_dataset
# ----> 2 df_test = create_dataset(return_dataset=True, save_dataset=True)
#       3 df_test
#
# <ipython-input-13-ac37f4a8466e> in create_dataset(save_dataset, return_dataset, output_path_filename)
#      65                     file_metadata[col] = re.findall(r'.*{} = (.*)\\n.*'.format(corners_dict[col]), file_str)[0]
#      66                 elif 'DATE' in col:
# ---> 67                     file_metadata[col] = re.findall(r'.*DATE_ACQUIRED = (.*)\\n.*', file_str)[0]
#      68             else:
#      69                 file_metadata[col] = matched[0].strip('"')
#
# IndexError: list index out of range

# %%
import numpy as np
modtran_atm.loc[np.round((-37.5090),-1).astype(int), 'April']
# Out:
# 'SAS'

# %% [markdown]
# ----------------

# %%
import requests
from usgs import api

# %%
api.login('ignacio.loayza', '4YApm7M32z3i4pm', catalogId='EE')
# Out:
# {'errorCode': None,
#  'error': '',
#  'data': '181cf2b59bb84ce9a19d1513ffc5e495',
#  'api_version': '1.4.0',
#  'access_level': 'user',
#  'catalog_id': 'default',
#  'executionTime': 0.40836596488952637}

# %%
api.search('LANDSAT_8_C1', 'EE', start_date='2017-04-01', end_date='2017-05-01', max_results=10, extended=True)
# Out:
# {'errorCode': None,
#  'error': '',
#  'data': {'numberReturned': 10,
#   'totalHits': 20399,
#   'firstRecord': 1,
#   'lastRecord': 10,
#   'nextRecord': 11,
#   'results': [{'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-22.07974, 80.13956],
#        [-16.19818, 78.78363],
#        [-8.20143, 79.71156],
#        [-13.5208, 81.19994],
#        [-22.07974, 80.13956]]]},
#     'sceneBounds': '-22.07974,78.78363,-8.20143,81.19994',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/002/LC08_L1TP_008002_20170501_20170515_01_T1.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080022017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080022017121LGN00/INVSVC/',
#     'entityId': 'LC80080022017121LGN00',
#     'displayId': 'LC08_L1TP_008002_20170501_20170515_01_T1',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080022017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080022017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080022017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1TP_008002_20170501_20170515_01_T1, Acquisition Date: 01-MAY-17, Path: 8, Row: 2'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-27.87358, 79.12495],
#        [-21.86099, 77.87725],
#        [-14.94724, 78.9537],
#        [-20.78274, 80.32878],
#        [-27.87358, 79.12495]]]},
#     'sceneBounds': '-27.87358,77.87725,-14.94724,80.32878',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/003/LC08_L1TP_008003_20170501_20170515_01_T1.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080032017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080032017121LGN00/INVSVC/',
#     'entityId': 'LC80080032017121LGN00',
#     'displayId': 'LC08_L1TP_008003_20170501_20170515_01_T1',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080032017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080032017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080032017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1TP_008003_20170501_20170515_01_T1, Acquisition Date: 01-MAY-17, Path: 8, Row: 3'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-32.67125, 78.02359],
#        [-26.72399, 76.87537],
#        [-20.78544, 78.06988],
#        [-26.79906, 79.33463],
#        [-32.67125, 78.02359]]]},
#     'sceneBounds': '-32.67125,76.87537,-20.78544,79.33463',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/004/LC08_L1TP_008004_20170501_20170515_01_T1.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080042017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080042017121LGN00/INVSVC/',
#     'entityId': 'LC80080042017121LGN00',
#     'displayId': 'LC08_L1TP_008004_20170501_20170515_01_T1',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080042017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080042017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080042017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1TP_008004_20170501_20170515_01_T1, Acquisition Date: 01-MAY-17, Path: 8, Row: 4'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-36.59935, 76.87942],
#        [-30.82783, 75.81912],
#        [-25.7156, 77.10542],
#        [-31.69079, 78.26956],
#        [-36.59935, 76.87942]]]},
#     'sceneBounds': '-36.59935,75.81912,-25.7156,78.26956',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/005/LC08_L1GT_008005_20170501_20170515_01_T2.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080052017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080052017121LGN00/INVSVC/',
#     'entityId': 'LC80080052017121LGN00',
#     'displayId': 'LC08_L1GT_008005_20170501_20170515_01_T2',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080052017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080052017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080052017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1GT_008005_20170501_20170515_01_T2, Acquisition Date: 01-MAY-17, Path: 8, Row: 5'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-39.97879, 75.66193],
#        [-34.44199, 74.68068],
#        [-30.04243, 76.04121],
#        [-35.85506, 77.11339],
#        [-39.97879, 75.66193]]]},
#     'sceneBounds': '-39.97879,74.68068,-30.04243,77.11339',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/006/LC08_L1GT_008006_20170501_20170515_01_T2.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080062017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080062017121LGN00/INVSVC/',
#     'entityId': 'LC80080062017121LGN00',
#     'displayId': 'LC08_L1GT_008006_20170501_20170515_01_T2',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080062017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080062017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080062017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1GT_008006_20170501_20170515_01_T2, Acquisition Date: 01-MAY-17, Path: 8, Row: 6'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-42.84953, 74.40765],
#        [-37.56677, 73.49496],
#        [-33.76038, 74.91435],
#        [-39.34888, 75.90611],
#        [-42.84953, 74.40765]]]},
#     'sceneBounds': '-42.84953,73.49496,-33.76038,75.90611',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/007/LC08_L1GT_008007_20170501_20170515_01_T2.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080072017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080072017121LGN00/INVSVC/',
#     'entityId': 'LC80080072017121LGN00',
#     'displayId': 'LC08_L1GT_008007_20170501_20170515_01_T2',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080072017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080072017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080072017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1GT_008007_20170501_20170515_01_T2, Acquisition Date: 01-MAY-17, Path: 8, Row: 7'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-45.31412, 73.1243],
#        [-40.28866, 72.27148],
#        [-36.97394, 73.73791],
#        [-42.31054, 74.6593],
#        [-45.31412, 73.1243]]]},
#     'sceneBounds': '-45.31412,72.27148,-36.97394,74.6593',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/008/LC08_L1GT_008008_20170501_20170515_01_T2.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080082017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080082017121LGN00/INVSVC/',
#     'entityId': 'LC80080082017121LGN00',
#     'displayId': 'LC08_L1GT_008008_20170501_20170515_01_T2',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080082017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080082017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080082017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1GT_008008_20170501_20170515_01_T2, Acquisition Date: 01-MAY-17, Path: 8, Row: 8'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-47.45308, 71.81767],
#        [-42.67655, 71.01703],
#        [-39.77, 72.52139],
#        [-44.84943, 73.38148],
#        [-47.45308, 71.81767]]]},
#     'sceneBounds': '-47.45308,71.01703,-39.77,73.38148',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/009/LC08_L1GT_008009_20170501_20170515_01_T2.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080092017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080092017121LGN00/INVSVC/',
#     'entityId': 'LC80080092017121LGN00',
#     'displayId': 'LC08_L1GT_008009_20170501_20170515_01_T2',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080092017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080092017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080092017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1GT_008009_20170501_20170515_01_T2, Acquisition Date: 01-MAY-17, Path: 8, Row: 9'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-49.32791, 70.493],
#        [-44.78504, 69.73767],
#        [-42.218, 71.27292],
#        [-47.0487, 72.07987],
#        [-49.32791, 70.493]]]},
#     'sceneBounds': '-49.32791,69.73767,-42.218,72.07987',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/010/LC08_L1GT_008010_20170501_20170515_01_T2.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080102017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080102017121LGN00/INVSVC/',
#     'entityId': 'LC80080102017121LGN00',
#     'displayId': 'LC08_L1GT_008010_20170501_20170515_01_T2',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080102017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080102017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080102017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1GT_008010_20170501_20170515_01_T2, Acquisition Date: 01-MAY-17, Path: 8, Row: 10'},
#    {'acquisitionDate': '2017-05-01',
#     'startTime': '2017-05-01',
#     'endTime': '2017-05-01',
#     'spatialFootprint': {'type': 'Polygon',
#      'coordinates': [[[-50.98687, 69.15304],
#        [-46.6609, 68.43722],
#        [-44.37795, 69.99782],
#        [-48.9736, 70.75856],
#        [-50.98687, 69.15304]]]},
#     'sceneBounds': '-50.98687,68.43722,-44.37795,70.75856',
#     'browseUrl': 'https://ims.cr.usgs.gov/browse/landsat_8_c1/2017/008/011/LC08_L1TP_008011_20170501_20170515_01_T1.jpg',
#     'dataAccessUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080112017121LGN00&node=INVSVC',
#     'downloadUrl': 'https://earthexplorer.usgs.gov/download/external/options/LANDSAT_8_C1/LC80080112017121LGN00/INVSVC/',
#     'entityId': 'LC80080112017121LGN00',
#     'displayId': 'LC08_L1TP_008011_20170501_20170515_01_T1',
#     'cloudCover': None,
#     'metadataUrl': 'https://earthexplorer.usgs.gov/metadata/xml/12864/LC80080112017121LGN00/',
#     'fgdcMetadataUrl': 'https://earthexplorer.usgs.gov/fgdc/12864/LC80080112017121LGN00/save_xml',
#     'modifiedDate': '2017-05-15',
#     'orderUrl': 'https://earthexplorer.usgs.gov/order/process?dataset_name=LANDSAT_8_C1&ordered=LC80080112017121LGN00&node=INVSVC',
#     'bulkOrdered': False,
#     'ordered': False,
#     'summary': 'Entity ID: LC08_L1TP_008011_20170501_20170515_01_T1, Acquisition Date: 01-MAY-17, Path: 8, Row: 11'}]},
#  'api_version': '1.4.0',
#  'access_level': 'user',
#  'catalog_id': 'EE',
#  'executionTime': 8.883380889892578}
